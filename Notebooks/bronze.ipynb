# %%
import pandas as pd
import os

# %%
df_sumula = (pd.read_excel(r"..\Excel\RANKING ASSOCIACAO BAYGON - 10 TEMPORADA.xlsx",
                   header=1))

# %%
df_sumula.to_csv(os.path.join(r"..\CSV\\", r'ranking.csv'), index=False)

# %%
df_sumula
# Out:
#       Boleiros  Ranking Geral  Artilharia  Assistências  Babas Conquistados  \
# 0      Adilson            995         183            90                 140
# 1           Zé            561          58            49                  85
# 2        Iagol            534          33            44                  94
# 3       Ed Rex            512          95            28                  71
# 4      Fabinho            503          21            12                  87
# ..         ...            ...         ...           ...                 ...
# 72       Rasta              5           0             1                   1
# 73      Barata              5           0             0                   0
# 74  Luiz Vitor              0           0             0                   0
# 75        Juiz              0           0             0                   0
# 76         Dáu              0           0             0                   0
#
# ...

# %%
df = pd.read_csv(r"..\CSV\ranking.csv")
df
# Out:
#       Boleiros  Ranking Geral  Artilharia  Assistências  Babas Conquistados  \
# 0      Adilson            995         183            90                 140
# 1           Zé            561          58            49                  85
# 2        Iagol            534          33            44                  94
# 3       Ed Rex            512          95            28                  71
# 4      Fabinho            503          21            12                  87
# ..         ...            ...         ...           ...                 ...
# 72       Rasta              5           0             1                   1
# 73      Barata              5           0             0                   0
# 74  Luiz Vitor              0           0             0                   0
# 75        Juiz              0           0             0                   0
# 76         Dáu              0           0             0                   0
#
# ...
